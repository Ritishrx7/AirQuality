# %% [markdown]
# <div style="text-align: center; color:royalblue;">
#     <h1> Project: "Real-Time" Data on Regulated Atmospheric Pollutant Concentrations 🧬🧪 </h1>
# </div>

# %% [markdown]
# ## Data Reference Table

# %% [markdown]
# <div style="text-align: center; font-weight: bold; font-size: 1.5em; color: #3A7CA5; margin-bottom: 20px;">
#     Table of Column Descriptions
# </div>
# <div style="max-height: 400px; overflow-y: auto; border: 1px solid #dddddd;">
# <table style="width:100%; border-collapse: collapse; text-align: left;">
#   <thead>
#     <tr style="background-color: #3A7CA5; color: white;">
#       <th style="padding: 10px; border: 1px solid #dddddd;">Column Label</th>
#       <th style="padding: 10px; border: 1px solid #dddddd;">Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">date de début</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">start date of the measurement</td>
#     </tr>
#     <tr style="background-color: #f2f2f2;">
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">date de fin</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">end date of the measurement</td>
#     </tr>
#     <tr>
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">organisme</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">name of the AASQA responsible for the measurement site and measurements</td>
#     </tr>
#     <tr style="background-color: #f2f2f2;">
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">code zas</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">code of the administrative surveillance area containing the sampling point</td>
#     </tr>
#     <tr>
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">zas</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">name of the administrative surveillance area containing the sampling point</td>
#     </tr>
#     <tr style="background-color: #f2f2f2;">
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">code site</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">measurement site code</td>
#     </tr>
#     <tr>
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">nom site</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">measurement site name</td>
#     </tr>
#     <tr style="background-color: #f2f2f2;">
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">type d'implantation</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">type of the measurement site location</td>
#     </tr>
#     <tr>
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">polluant</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">measured pollutant</td>
#     </tr>
#     <tr style="background-color: #f2f2f2;">
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">type d'influence</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">type of influence for the given pollutant</td>
#     </tr>
#     <tr>
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">discriminant</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">configuration discriminant code</td>
#     </tr>
#     <tr style="background-color: #f2f2f2;">
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">réglementaire</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">regulatory status of the data (yes/no)</td>
#     </tr>
#     <tr>
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">type d'évaluation</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">type of evaluation corresponding to the measurement</td>
#     </tr>
#     <tr style="background-color: #f2f2f2;">
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">procédure de mesure</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">measurement procedure</td>
#     </tr>
#     <tr>
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">type de valeur</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">type of data or statistic</td>
#     </tr>
#     <tr style="background-color: #f2f2f2;">
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">valeur</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">rounded value</td>
#     </tr>
#     <tr>
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">valeur brute</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">raw value</td>
#     </tr>
#     <tr style="background-color: #f2f2f2;">
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">unité de mesure</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">unit of data measurement</td>
#     </tr>
#     <tr>
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">taux de saisie</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">percentage of valid data over the measurement period</td>
#     </tr>
#     <tr style="background-color: #f2f2f2;">
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">couverture temporelle</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">percentage of the period covered by measurements</td>
#     </tr>
#     <tr>
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">couverture de données</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">percentage of valid data over the period (product of entry rate and temporal coverage)</td>
#     </tr>
#     <tr style="background-color: #f2f2f2;">
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">code qualité</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">measurement quality code (A,R,I,..)</td>
#     </tr>
#     <tr>
#       <td style="padding: 8px; border: 1px solid #dddddd; font-weight: bold;">validité</td>
#       <td style="padding: 8px; border: 1px solid #dddddd;">measurement validity</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The different types of pollutants:
#
# * $C_6H_6$: Benzene
# * $CO$: Carbon Monoxide
# * $NO$: Nitric Oxide
# * $NO_2$: Nitrogen Dioxide
# * $NO_X$ as $NO_2$: Nitrogen Oxides (expressed as $NO_2$ equivalent)
# * $O_3$: Ozone
# * $PM_{10}$: Fine Particulate Matter (diameter ≤ 10 micrometers)
# * $PM_{2.5}$: Fine Particulate Matter (diameter ≤ 2.5 micrometers)
# * $SO_2$: Sulfur dioxide

# %% [markdown]
# ## Importing Libraries

# %%
import time
import pandas as pd
import urllib
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import datetime as dt
from matplotlib.ticker import FuncFormatter
import scipy

# %% [markdown]
# ## Configurations

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Data Query

# %%
BASE_URL = "https://files.data.gouv.fr/lcsqa/concentrations-de-polluants-atmospheriques-reglementes/temps-reel/"

years = ["2023", "2024"]
FILE_BASE_FORMAT = "FR_E2_"
specific_hours = ["00:00:00", "08:00:00", "16:00:00"]

# %%
def get_all_month(year, month):
    """Downloads all available daily data for a specific month and filters it for 3 specific hours."""
    url = f"{BASE_URL}/{year}/{FILE_BASE_FORMAT}{year}-{month}"
    df = pd.DataFrame()
    
    for i in range(1, 32):  # Loop through all possible days of the month
        # Format day with leading zero if needed
        day = f"{i:02d}"

        try:
            daily_df = pd.read_csv(f"{url}-{day}.csv", sep=";")
            
            # Filter rows to keep only the specific hours
            if 'Date de début' in daily_df.columns:
                # Convert 'Date de début' to datetime 
                daily_df['Heure'] = pd.to_datetime(daily_df['Date de début']).dt.time
                daily_df = daily_df[daily_df['Heure'].astype(str).isin(specific_hours)]
                daily_df = daily_df.drop(columns=['Heure'])  # Drop the temporary 'Heure' column

        except FileNotFoundError:
            print(f"FileNotFound: {url}-{day}.csv")
            continue
        except urllib.error.HTTPError:
            print(f"FileNotFound: {url}-{day}.csv")
            continue

        # Concatenate the daily data into the monthly DataFrame
        df = pd.concat([df, daily_df]).reset_index(drop=True)

    return df


def get_all_year(year):
    """Downloads all monthly data for a year and filters it."""
    df = pd.DataFrame()
    
    for i in range(1, 13):  # Loop through all months
        month = f"{i:02d}"  # Format month with leading zero if needed
        print(f"Downloading month: {i} of year {year}")
        monthly_df = get_all_month(year, month)
        
        # Concatenate the monthly data into the yearly DataFrame
        df = pd.concat([df, monthly_df]).reset_index(drop=True)

    return df

# UNCOMMENT TO DOWNLOAD DATA

"""
# Create an empty DataFrame to hold data for both years
combined_df = pd.DataFrame()

# Loop through the years 2023 and 2024 and concatenate their data into one DataFrame
for y in years:
    yearly_df = get_all_year(y)
    combined_df = pd.concat([combined_df, yearly_df]).reset_index(drop=True)

# Save the combined DataFrame as a single CSV file for both years
combined_df.to_csv("AirQuality_2023_2024.csv", index=False)
"""
# Out:
# '\n# Create an empty DataFrame to hold data for both years\ncombined_df = pd.DataFrame()\n\n# Loop through the years 2023 and 2024 and concatenate their data into one DataFrame\nfor y in years:\n    yearly_df = get_all_year(y)\n    combined_df = pd.concat([combined_df, yearly_df]).reset_index(drop=True)\n\n# Save the combined DataFrame as a single CSV file for both years\ncombined_df.to_csv("AirQuality_2023_2024.csv", index=False)\n'

# %% [markdown]
# ### Load Data from Local File
#
# + History: January 1, 2023 - October 24, 2024

# %%
file_name = "./AirQuality_2023_2024.csv"
df = pd.read_csv(file_name, sep = ",", header= 0, parse_dates=["Date de début", "Date de fin"],
                 dtype={"Organisme": str, "code zas": str, "Zas": str, "code site": str,
                        "nom site": str, "type d'implantation" : str, "Polluant": str,
                        "type d'influence": str, "discriminant": str, "Réglementaire": str,
                        "type d'évaluation": str, "procédure de mesure": str, "type de valeur": str,
                       "valeur": float, "valeur brute":float, "unité de mesure": str, "code qualité": str, "validité": str})

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Functions

# %%
def df_metrics(df):
    '''
Cette fonction renvoi:
Le taux de valeurs non-nulles par variable
Le nombre de valeurs non-nulles par variable
Le taux de valeurs par variable
    '''
    fill_rate = df.notna().mean() * 100 
    num_values = df.count()  
    na_rate = df.isna().mean() * 100 

    metrics_df = pd.DataFrame({
        'Fill Rate (%)': fill_rate,
        'Number of Values': num_values,
        'NA Rate (%)': na_rate
    }).sort_values(by =["Fill Rate (%)"], ascending=False)
    return metrics_df

# %%
def cal_bounds(df, group_col, val_col):
    """
    Calculate the 1.5 * IQR lower and upper bounds for each group of a categorical column.
    
    Parameters:
    df (pd.DataFrame): The input DataFrame.
    group_col (str): The name of the categorical column to group by.
    val_col (str): The name of the column with numerical values.

    Returns:
    pd.DataFrame: A DataFrame with groups and their corresponding IQR bounds.
    """
    # Create an empty DataFrame to store the bounds for each group
    bounds_list = []

    # Group by the categorical column and calculate bounds for each group
    for group, group_df in df.groupby(group_col):
        Q1 = group_df[val_col].quantile(0.25)
        Q3 = group_df[val_col].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Append results as a dictionary to the list
        bounds_list.append({
            group_col: group,
            'Lower Bound': lower_bound,
            'Upper Bound': upper_bound
        })

    # Convert the list of dictionaries to a DataFrame
    bounds_df = pd.DataFrame(bounds_list)

    return bounds_df

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Renaming column names

# %%
df.rename(columns={
    "Date de début": "date_debut", 
    "Date de fin": "date_fin", 
    "code zas": "code_zas", 
    "code site": "code_site", 
    "type d'implantation": "implantation_type", 
    "type d'influence": "influence_type", 
    "unité de mesure": "unite_mesure", 
    "type d'évaluation": "type_evaluation", 
    "procédure de mesure": "procedure_de_mesure", 
    "type de valeur": "type_de_valeur", 
    "nom site": "nom_site", 
    "taux de saisie": "taux_de_saisie", 
    "couverture temporelle": "couverture_temporelle", 
    "couverture de données": "couverture_de_donnees",
    "valeur brute": "valeur_brute",
    "Réglementaire": "reglementaire",
    "code qualité": "code_qualite"
    }, inplace=True)

# %% [markdown]
# #### Descriptive Statistics of Columns (A)

# %%
df_metrics(df)
# Out:
#                        Fill Rate (%)  Number of Values  NA Rate (%)
# date_debut                100.000000           4221750     0.000000
# influence_type            100.000000           4221750     0.000000
# code_qualite              100.000000           4221750     0.000000
# unite_mesure              100.000000           4221750     0.000000
# type_de_valeur            100.000000           4221750     0.000000
# procedure_de_mesure       100.000000           4221750     0.000000
# type_evaluation           100.000000           4221750     0.000000
# date_fin                  100.000000           4221750     0.000000
# reglementaire             100.000000           4221750     0.000000
# Polluant                  100.000000           4221750     0.000000
# implantation_type         100.000000           4221750     0.000000
# nom_site                  100.000000           4221750     0.000000
# code_site                 100.000000           4221750     0.000000
# ...

# %% [markdown]
# #### Dropping Variables with 100% Null rate

# %%
df.drop(columns = ["taux_de_saisie", "couverture_temporelle", "couverture_de_donnees"], inplace=True)

# %% [markdown]
# #### Dropping duplicate variables and unusable variables
# + Remove the column "Valeur Brute" and keep "Valeur" as verified by the national technical reference.
# + Remove the "discriminant" variable because it represents an internal reference within the database.
# + Remove the "Réglementaire" variable as all data rows have the value "Oui."
# + Use the "validité" variable with a value >= 1 to retain reliable data; otherwise, delete the rows.

# %%
df.drop(columns=["valeur_brute", "discriminant", "reglementaire", "code_qualite"], inplace= True)

# %% [markdown]
# #### Dropping rows with missing values

# %%
r = df[df["valeur"].isna()]["validité"].unique()
print(f"Amongst NA values for 'valeur', unique validity values: {r.tolist()}")
# Out:
# Amongst NA values for 'valeur', unique validity values: ['-1']

# %%
df.dropna(subset = ["valeur"], inplace=True)

# %% [markdown]
# #### Dropping rows with negative values (Data error)

# %%
df.drop(df.loc[df["valeur"]<0].index, inplace=True)

# %%
df = df.reset_index(drop=True)

# %%
df[df["valeur"] < 0].shape[0]/df.shape[0] #Check for negative values
# Out:
# 0.0

# %% [markdown]
# #### Correction of variable names and values

# %%
df['unite_mesure'] = df['unite_mesure'].str.replace("µg-m3", "µg/m3")
df['unite_mesure'] = df['unite_mesure'].str.replace("mg-m3", "mg/m3")

# %% [markdown]
# #### Descriptive Statistics of Columns (B)

# %%
df_metrics(df)
# Out:
#                      Fill Rate (%)  Number of Values  NA Rate (%)
# date_debut                   100.0           3950055          0.0
# date_fin                     100.0           3950055          0.0
# Organisme                    100.0           3950055          0.0
# code_zas                     100.0           3950055          0.0
# Zas                          100.0           3950055          0.0
# code_site                    100.0           3950055          0.0
# nom_site                     100.0           3950055          0.0
# implantation_type            100.0           3950055          0.0
# Polluant                     100.0           3950055          0.0
# influence_type               100.0           3950055          0.0
# type_evaluation              100.0           3950055          0.0
# procedure_de_mesure          100.0           3950055          0.0
# type_de_valeur               100.0           3950055          0.0
# ...

# %% [markdown]
# #### Duplicate rows verification
# + No duplicates

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date_debut, date_fin, Organisme, code_zas, Zas, code_site, nom_site, implantation_type, Polluant, influence_type, type_evaluation, procedure_de_mesure, type_de_valeur, valeur, unite_mesure, validité]
# Index: []

# %% [markdown]
# We can remove columns which are entirely valid or does not bring any information for our data analysis

# %%
df["validité"].unique()
# Out:
# array(['1'], dtype=object)

# %%
df = df.drop(columns=["type_evaluation", "procedure_de_mesure", "validité"])

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# We have two different date: date_debut and date_fin but we are only interested in one of those. For clarity, let's rename date_debut date and remove date_fin

# %%
df = df.rename({"date_debut":"date"}, axis=1)
df = df.drop("date_fin", axis=1)

# %% [markdown]
# #### Verification of Modalities: Qualitative Variables

# %%
categorical_columns = ["implantation_type","influence_type","type_de_valeur"]

for cat in categorical_columns: 
    print(f"Unique categories for {cat}: {df[cat].nunique()}")
# Out:
# Unique categories for implantation_type: 5
# Unique categories for influence_type: 3
# Unique categories for type_de_valeur: 2

# %%
for cat in ["implantation_type","influence_type","type_de_valeur"]: 
    print(f"{cat} unique values: {df[cat].unique()}")
# Out:
# implantation_type unique values: ['Urbaine' 'Rurale près des villes' 'Périurbaine' 'Rurale régionale'
#  'Rurale nationale']
# influence_type unique values: ['Fond' 'Industrielle' 'Trafic']
# type_de_valeur unique values: ['moyenne horaire validée' 'moyenne horaire brute']

# %% [markdown]
# Let's investigate the type_de_valeur feature

# %%
print(f"There are {df[df['type_de_valeur'] == 'moyenne horaire brute'].shape[0]} lines with moyenne horaire brute")
# Out:
# There are 9242 lines with moyenne horaire brute

# %% [markdown]
# If type_de_valeur is moyenne horaire brute, it means the values haven't been verified by a quality assurance process. There are only 9026 lines with this so we decide to remove those lines and remove the column entirely because it'll be left with only one unique value.

# %%
df = df.loc[df["type_de_valeur"] == "moyenne horaire validée"]
df = df.drop(columns=["type_de_valeur"])

# %%
df_metrics(df)
# Out:
#                    Fill Rate (%)  Number of Values  NA Rate (%)
# date                       100.0           3940813          0.0
# Organisme                  100.0           3940813          0.0
# code_zas                   100.0           3940813          0.0
# Zas                        100.0           3940813          0.0
# code_site                  100.0           3940813          0.0
# nom_site                   100.0           3940813          0.0
# implantation_type          100.0           3940813          0.0
# Polluant                   100.0           3940813          0.0
# influence_type             100.0           3940813          0.0
# valeur                     100.0           3940813          0.0
# unite_mesure               100.0           3940813          0.0

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Distribution of Quantitative Variables

# %%
polluants = df["Polluant"].unique().tolist()
polluants
# Out:
# ['NO', 'NO2', 'O3', 'NOX as NO2', 'PM10', 'PM2.5', 'C6H6', 'SO2', 'CO']

# %%
describe_df = pd.DataFrame(columns=polluants, index=["count","mean","min","25%","50%","75%","max","std"])

# %%
for p in polluants: 
    describe_df[p] = df[df["Polluant"] == p].describe()["valeur"]

describe_df
# Out:
#                   NO            NO2             O3     NOX as NO2  \
# count  662453.000000  716695.000000  577247.000000  709319.000000
# mean        7.348360      13.565232      57.345690      23.942091
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.600000       4.200000      39.700000       5.300000
# 50%         1.600000       8.700000      58.300000      11.200000
# 75%         5.600000      17.900000      74.500000      26.000000
# max       634.200000     199.200000     206.600000    1147.100000
# std        17.771449      13.872236      26.022134      37.627945
#
#                 PM10          PM2.5          C6H6            SO2            CO
# count  652648.000000  449901.000000  12047.000000  129410.000000  31093.000000
# mean       15.065301       8.073847      1.032165       2.205477      0.238574
# min         0.000000       0.000000      0.000000       0.000000      0.000000
# ...

# %% [markdown]
# #### Box Plot
# + The are some outliers that we need to handle in the polluant variable. This is illustrated below:

# %%
plt.figure(figsize=(10,12))
sns.boxplot(data=df, x="Polluant", y="valeur", hue="Polluant", palette="Set1", legend=False)
# plt.savefig("Box_plot.png", dpi = 300)

# %% [markdown]
# #### Handling outliers

# %%
cal_bounds(df, group_col='Polluant', val_col='valeur')
# Out:
#      Polluant  Lower Bound  Upper Bound
# 0        C6H6       -1.270        2.570
# 1          CO       -0.095        0.513
# 2          NO       -6.900       13.100
# 3         NO2      -16.350       38.450
# 4  NOX as NO2      -25.750       57.050
# 5          O3      -12.500      126.700
# 6        PM10       -9.200       35.600
# 7       PM2.5       -5.500       19.300
# 8         SO2       -1.750        4.250

# %%
filtre = (
    ((df["Polluant"]=="NO") & (df["valeur"] < 11.5)) | 
    ((df["Polluant"]=="NO2") & (df["valeur"] < 38.2)) |
    ((df["Polluant"]=="O3") & (df["valeur"] < 127)) |
    ((df["Polluant"]=="NOX as NO2") & (df["valeur"] < 57)) | 
    ((df["Polluant"]=="PM10") & (df["valeur"] < 36)) |
    ((df["Polluant"]=="PM2.5") & (df["valeur"] < 20)) |
    ((df["Polluant"]=="C6H6") & (df["valeur"] < 3)) | 
    ((df["Polluant"]=="SO2") & (df["valeur"] < 4.2)) |
    ((df["Polluant"]=="CO") & (df["valeur"] < 510))
)

plt.figure(figsize=(12,12))
sns.boxplot(data=df[filtre], x="Polluant", y="valeur", hue="Polluant", palette="Set1", legend=False)
plt.savefig("box_plot.png", dpi = 300)

# %% [markdown]
# Let's look at the outliers

# %%
df[(df["Polluant"] == "PM10") & (df["valeur"] > 500)].head()
# Out:
#                        date                  Organisme   code_zas       Zas  \
# 1113097 2023-07-04 08:00:00  ATMO AUVERGNE-RHÔNE-ALPES  FR84ZAG01  ZAG LYON
#
#         code_site         nom_site implantation_type Polluant influence_type  \
# 1113097   FR20013  A7 SUD LYONNAIS       Périurbaine     PM10         Trafic
#
#          valeur unite_mesure
# 1113097   526.7        µg/m3

# %% [markdown]
# * Those are validated values + fixed values on validated hours so its likely to be a peak in pollution at that time rather than corrupted values

# %%
date_filter = df["date"].dt.date == pd.to_datetime("2023-07-04").date()
zag_filter = df["Zas"] == "ZAG LYON"
pol_filter = df["Polluant"] == "PM10"
df[date_filter & zag_filter & pol_filter].head()
# Out:
#                        date                  Organisme   code_zas       Zas  \
# 1113096 2023-07-04 00:00:00  ATMO AUVERGNE-RHÔNE-ALPES  FR84ZAG01  ZAG LYON
# 1113097 2023-07-04 08:00:00  ATMO AUVERGNE-RHÔNE-ALPES  FR84ZAG01  ZAG LYON
# 1113098 2023-07-04 16:00:00  ATMO AUVERGNE-RHÔNE-ALPES  FR84ZAG01  ZAG LYON
# 1113114 2023-07-04 00:00:00  ATMO AUVERGNE-RHÔNE-ALPES  FR84ZAG01  ZAG LYON
# 1113115 2023-07-04 08:00:00  ATMO AUVERGNE-RHÔNE-ALPES  FR84ZAG01  ZAG LYON
#
#         code_site         nom_site implantation_type Polluant influence_type  \
# 1113096   FR20013  A7 SUD LYONNAIS       Périurbaine     PM10         Trafic
# 1113097   FR20013  A7 SUD LYONNAIS       Périurbaine     PM10         Trafic
# 1113098   FR20013  A7 SUD LYONNAIS       Périurbaine     PM10         Trafic
# 1113114   FR20017          GERLAND           Urbaine     PM10           Fond
# 1113115   FR20017          GERLAND           Urbaine     PM10           Fond
#
#          valeur unite_mesure
# ...

# %% [markdown]
# #### Proportion of pollutants

# %%
grouped_rel = df.groupby(["date", "implantation_type", "Polluant"], as_index=False)["valeur"].sum()

# %%
pollutant_totals = grouped_rel.groupby("Polluant")["valeur"].sum().sort_values(ascending=False)
colors = sns.color_palette(palette = "Set1", n_colors=len(pollutant_totals))
explode = [0.05] * len(pollutant_totals)  # Slightly "explode" each slice

plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(
    pollutant_totals, 
    labels=pollutant_totals.index, 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=colors, 
    explode=explode, 
    shadow=True, 
    textprops={'fontsize': 8}, 
    wedgeprops={'linewidth': 1, 'edgecolor': 'white'},
    labeldistance=1.1
)

for text in texts:
    text.set_fontsize(12)  # Set font size for labels
for autotext in autotexts:
    autotext.set_fontsize(12)  # Set font size for percentages
    autotext.set_color("black")
    autotext.set_bbox({
    'facecolor': 'lightyellow',  # Light yellow background
    'edgecolor': 'black',        # Black border around the box
    'boxstyle': 'round,pad=0.3', # Rounded corners with padding
    'linewidth': 1               # Border thickness
    })

plt.title("Percentage of Pollution by Pollutant", fontsize=16)
# plt.savefig("piechart.png", dpi = 300, transparent = True)
plt.show()

# %% [markdown]
# #### Areas of Pollutants

# %% [markdown]
# The "Fond" influence type refers to background pollution that is ambient in areas without specific traffic peaks or industrial zones.

# %%
grouped = df.groupby(["influence_type", "Polluant"])["valeur"].mean().unstack()
grouped
# Out:
# Polluant            C6H6        CO         NO        NO2  NOX as NO2  \
# influence_type
# Fond                 NaN  0.232846   3.601652  10.590426   15.598874
# Industrielle    1.144951  0.172543   2.205429   7.742198   10.685575
# Trafic          0.588094  0.269415  18.120615  22.763264   49.943220
#
# Polluant               O3       PM10     PM2.5       SO2
# influence_type
# Fond            57.333811  13.774047  7.818400  1.731780
# Industrielle    59.530173  15.724523  8.153293  2.469158
# Trafic                NaN  18.443236  8.970773  1.360000

# %% [markdown]
# #### Bar Chart for Each Polluant

# %%
fig, axs = plt.subplots(3,3, figsize=(12,12))

# Générer un barplot pour chaque polluant dans chaque sous-graphe
for idx, (polluant, ax) in enumerate(zip(polluants, axs.ravel())):

    # Obtenir les valeurs moyennes de pollution pour chaque type d'influence pour le polluant actuel
    values = grouped[polluant]
    
    # Créer un barplot
    ax.bar(values.index, values.values)
    ax.set_title(f'{polluant}')
    ax.set_xlabel('Type d\'influence')
    ax.set_ylabel('Valeur moyenne de pollution')
    ax.grid(True)

# Ajuster l'espacement pour éviter le chevauchement
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
# plt.savefig("barplot.png", dpi = 300, transparent = True)
plt.show()

# %%
grouped_impl = df.groupby(["implantation_type", "Polluant"])["valeur"].mean().unstack()
grouped_impl.tail()
# Out:
# Polluant                    C6H6        CO        NO        NO2  NOX as NO2  \
# implantation_type
# Périurbaine             1.144951  0.233524  6.062257  10.810686   19.129264
# Rurale nationale             NaN  0.143819  0.439005   2.223224    2.821630
# Rurale près des villes       NaN  0.239063  2.082839   5.889541    8.649852
# Rurale régionale             NaN       NaN  1.081682   4.427037    5.732556
# Urbaine                 0.588094  0.246011  8.471542  15.533023   27.686475
#
# Polluant                       O3       PM10     PM2.5       SO2
# implantation_type
# Périurbaine             57.796363  16.166230  8.618958  2.175167
# Rurale nationale        66.266492   9.452466  5.996837       NaN
# Rurale près des villes  62.335398  12.917405  6.771169  2.340688
# Rurale régionale        62.589732  10.768426  6.876733  2.049090
# Urbaine                 54.940371  15.327896  8.218624  2.201700

# %%
fig, axs = plt.subplots(3, 3, figsize=(12, 16))

# Générer un barplot pour chaque polluant dans chaque sous-graphe
for idx, (polluant, ax) in enumerate(zip(polluants, axs.ravel())):


    values = grouped_impl[polluant]
    # Créer un barplot
    ax.bar(values.index, values.values)
    ax.set_title(f'{polluant}')
    ax.set_xlabel('Type d\'implantation')
    ax.set_ylabel('Valeur moyenne de pollution')
    ax.grid(True)

    # Définir explicitement les emplacements des ticks!
    ax.set_xticks(range(len(values.index)))
    ax.set_xticklabels(values.index, rotation=45, ha='right')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# #### Polluants Time Series

# %%
df_line = df.groupby([df["Polluant"],df['date']], as_index=False)["valeur"].sum()

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=df_line, x='date', y='valeur', hue='Polluant', linewidth=1,estimator=sum)
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x/1000:.0f}K'))
plt.xlabel("Pollutant record date")
plt.ylabel("Pollutant concentration (mg/m3)")
plt.ylim((0, 60_000))
# plt.savefig("Time_series.png")
# Out:
# (0.0, 60000.0)

# %% [markdown]
# #### Seasonal Rolling average over T time (T=90)
# + We note that we have 3 data points per pollutants per day. We want to display a moving average over 3 months for weather seasonality. Thus, we take 90*3 = 270 data points.
# + We observe that the pollutants $NO_X$ and $NO_2$ follow the same trends.
# + We see that pollutants $O_3$ and $NO_X$ are potentially inversely correlated. We will create a correlation graph to analyze in detail if there are correlations between the pollutants.

# %%
df_line['MA_values'] = df_line.groupby('Polluant')['valeur'].transform(lambda x: x.rolling(window=90*3, min_periods=1).mean())
sns.lineplot(data=df_line, x='date', y='MA_values', hue='Polluant', linewidth=1.5)
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x/1000:.0f}K'))
plt.legend(title='Polluant', bbox_to_anchor=(1.3, 1), loc='upper right')
# plt.savefig("Time_series_90.png", bbox_inches = "tight", dpi=300, transparent = True)
plt.show()

# %% [markdown]
# #### Correlation Matrix
# + Using a 3 months seasonal window, we confirm that there is a significant correlation between the pollutants. We confirm the very strong inverse correlation of $O3$ with $CO$, $NO$, $NO2$ and $NOX$. We also note a strong inverse correlation of $C6H6$ and $PM2.5$. We also deduce a higher correlation between among other pollutants.

# %%
df_corr = df_line.pivot(columns = "Polluant", values = "MA_values", index = "date")

# %%
df_corr = df_corr.fillna(0) # On remplace les NaN par 0 pour le calcul de la corrélation.

# %%
matrix = df_corr.corr(method = 'pearson')
sns.heatmap(matrix, annot=True, vmax=1, vmin=-1, center = 0, cmap='vlag', annot_kws = {"size": 8})
plt.xlabel("")
plt.ylabel("")
# plt.savefig("Corr.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# #### Bar plot of landscape Area
#
# We can see a higher concentration of pollutants in city regions $\bf{\text{Périurbaine}}$ and $\bf{\text{Urbaine}}$ compared to rural or close to rural areas. This is explained with the higher economic activity in cities by vehicles, factories and human activity in those regions.

# %%
impl_poll = df.groupby(["implantation_type", "Polluant"], as_index= False)["valeur"].sum().sort_values(by = ["valeur"], ascending=False)

# %%
plt.figure(figsize=(8, 6))
ax = sns.barplot(data=impl_poll, x="implantation_type", y="valeur", hue="Polluant", palette="Set1")

ax.legend(title='Polluant', bbox_to_anchor=(1.05, 1), loc='upper left')
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x / 1_000_000)}'))

ax.set_xlabel("Type d'implantation", fontsize=9)
ax.set_ylabel("Valeur (en Millions (mg/m3))", fontsize=9)
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
# plt.savefig("bar_plot_region.png", dpi = 300, transparent = True)
plt.show()

# %% [markdown]
# #### Relational scatter plot of City Area
#
# + We can see that Paris, Nouvelle Aquitaine and Grand-Est are the 3 most regions that emits the most amount of pollutants. This is somehow an expected conclusion due to Paris being the capital of France. The other two regions are famous among locals and tourists due to the landscape and beautiful architecture.
# + We can see that the pollutants concentrations is decreasing in Paris, Nouvelle-Aquitaine and Grand-Est. However the pollutants in other sites of measurement fluntuates around the same levels.
# + Across Europe, there has been a concerted effort to reduce emissions, particularly from industrial activities, agriculture, and transport. These efforts are supported by policies such as the European Green Deal and Zero Pollution Action Plan, which aim to cut harmful emissions and improve air quality [https://www.eea.europa.eu/publications/europes-air-quality-status-2023].
# + Stricter EU air quality standards, including reductions in acceptable levels for particulate matter (PM2.5 and PM10) and sulfur dioxide, have played a role in improving air quality. The European Commission has pushed for more ambitious air quality standards, aligning them with World Health Organization (WHO) recommendations [https://www.eea.europa.eu/publications/europes-air-quality-status-2024].
# + The decline in particulate matter concentrations is also partly due to reductions in secondary aerosols, which are formed from other pollutants like nitrogen oxides and ammonia. Even though the emissions of primary particulate matter have been reduced, the additional impact of secondary pollutants has further helped lower overall particulate pollution levels [https://www.eionet.europa.eu/etcs/etc-he/products/etc-he-products/etc-he-reports/etc-he-report-2023-8-long-term-trends-of-air-pollutants-at-european-and-national-level-2005-2021].

# %%
df["Date_mois"] = df["date"].dt.to_period("M")

# %%
grouped_ville = df.groupby(["Date_mois", "Zas"], as_index=False)["valeur"].sum()
top_200_valeur = grouped_ville.nlargest(200, "valeur").sort_values(by = "Date_mois")
top_200_valeur.head(1)
# Out:
#   Date_mois                Zas      valeur
# 8   2023-01  ZAG MARSEILLE-AIX  143608.828

# %%
g_zas = sns.catplot(data=top_200_valeur, 
                x="Date_mois", 
                y="valeur", 
                hue="Zas", 
                kind="point", 
                height=7, 
                aspect=2,
                palette = "Set1")  
plt.xticks(rotation=45, ha='right')

#Enable grid
plt.xlabel("Pollutant record date")
plt.ylabel("Pollutant concentration (mg/m3)")
g_zas.despine(left=True, bottom=True)
plt.grid(True, linestyle='--', alpha=0.3)
g_zas.set(ylim=(0, 600_000)) 
g_zas.legend.set_bbox_to_anchor((1.05, .8))
g_zas.set(yticks=[0, 100_000, 200_000, 300_000, 400_000, 500_000, 600_000])
g_zas.ax.set_yticklabels(['0k', '100k', '200k', '300k', '400k', '500k', '600k'])
plt.tight_layout()
plt.savefig("Zas_pollutants.png", bbox_inches='tight', dpi = 300, transparent = True)
plt.show()

# %% [markdown]
# #### Kernel Pollutant density
# + The distribution of the pollutant $O{3}$ has the highest peak due higher concentrations levels. This is followed by $NO{X}$, $PM{10}$, and $NO{2}$ with has high variance. We also notice $CO$ has small values concentration show very little variation concentrations.

# %%
grouped_poll = df.groupby(["date", "Polluant"], as_index=False)["valeur"].sum()

# %%
sns.kdeplot(data = grouped_poll, x = "valeur", hue = "Polluant", cumulative=False, fill = True, multiple="layer", weights = "valeur")
plt.xlim(-1000, 60_000)
# Out:
# (-1000.0, 60000.0)

# %% [markdown]
# #### Weekly average evolution of pollutant
#
# We look at the weekly evolution of each pollutant. We group by average value for each daily point (3 points a day)

# %%
weekly_evol = df.copy()
weekly_evol["day_of_week"] = weekly_evol["date"].dt.day_name()
weekly_evol["hour"] = weekly_evol["date"].dt.hour
day_map = {
    'Monday': 'Mo', 'Tuesday': 'Tu', 'Wednesday': 'We', 'Thursday': 'Th',
    'Friday': 'Fr', 'Saturday': 'Sa', 'Sunday': 'Su'
}
weekly_evol["day_hour"] = weekly_evol["day_of_week"].map(day_map) + "-" + weekly_evol["hour"].apply(lambda x: f"{x:02}")
weekly_evol = weekly_evol.groupby(["day_hour", "Polluant"])["valeur"].mean().reset_index()

# %% [markdown]
# We make three different groups to improve the visuals on the plot, otherwise, because the average values of some pollutant are much smaller than others, it'll be hard to see

# %%
# Define pollutant groups
group1 = ['O3', 'NOX as NO2']
group2 = ['PM10', 'PM2.5', 'NO2', 'NO']
group3 = ['SO2', 'C6H6']
group4 = ['CO']
fig, axs = plt.subplots(2,2,figsize=(10,8))
# Function to plot a group of pollutants
def plot_pollutant_group(ax, pollutants, title):
    
    for pollutant in pollutants:
        pollutant_data = weekly_evol[weekly_evol['Polluant'] == pollutant]
        ax.plot(
            pollutant_data['day_hour'], 
            pollutant_data['valeur'], 
            marker='o', 
            linestyle='-', 
            label=pollutant,
        )
    
    ax.set_xlabel('Hour of Day')
    ax.set_ylabel('Average Value')
    ax.set_title(f'Avg Pollutant for {title}')
    ax.legend(title='Pollutant', loc="best")
    ax.tick_params(axis="x", rotation=45) 
    ax.grid(True)

# Plot each group
plot_pollutant_group(axs[0,0], group1, "Group 1 (O3, NOX as NO2)")
plot_pollutant_group(axs[0,1], group2, "Group 2 (PM10, PM2.5, NO2, NO)")
plot_pollutant_group(axs[1,0], group3, "Group 3 (SO2, C6H6)")
plot_pollutant_group(axs[1,1], group4, "Group 4 (CO)")

fig.tight_layout()
# plt.savefig("avg_pollutants.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# We can see clear patterns in that data, which can be easily explained by Human activity and pollutant type.
#
# * Peaks in pollution at 9am and 5pm: This align with rush hours, where increased vehicular traffic contributes to higher emission of most pollutants
# * Weekend reductions: We can see a drop in emission of pollutants directly related to vehicle exhaust and industrial activities ($PM_{10}$, $NO$, $NO_2$, $PM_{2.5}$, $NO_x$ as $NO_2$, $C_6H_6$, and $CO$)
# * For Pollutants not directly related to vehicle exhaust and industrial activities, we see a minimal drop on weekends ($O_3$ and $SO_2$)

# %% [markdown]
# #### Yearly average evolution of pollutant
#
# We look at the yearly evolution of each pollutant. We group by average value for each day of the year

# %%
yearly_evol = df.copy()
yearly_evol["MM-DD"] = df["date"].dt.strftime("%m-%d")
yearly_evol = yearly_evol.groupby(["MM-DD", "Polluant"])["valeur"].mean().reset_index()

# %%
fig, axs = plt.subplots(3,3,figsize=(14,8))

for i,p in enumerate(polluants): 

    ax = axs[i//3,i%3]
    pollutant_data = yearly_evol[yearly_evol['Polluant'] == p]
    ax.plot(
        pollutant_data['MM-DD'], 
        pollutant_data['valeur'], 
        marker='o', 
        linestyle='-', 
        label=p
    )

    ax.set_xlabel('Date')
    ax.set_ylabel('Average Value')
    ax.set_title(f'Avg Pollutant for {p}')

    # We only want to print the beginning of months in the graph
    monthly_ticks = [date for date in yearly_evol['MM-DD'].unique() if date.endswith('-01')]
    ax.set_xticks(monthly_ticks)
    ax.tick_params(axis="x", rotation=45)

fig.tight_layout()
plt.show()

# %% [markdown]
# Let's look at Paris pollution

# %%
paris = df[df["Zas"] == "ZAG PARIS"]

# %%
grouped_paris = paris.groupby(["Polluant"])["valeur"].mean()
import numpy as np 

plt.figure(figsize=(10, 6))


num_bars = len(grouped_paris)
colors = plt.cm.viridis(np.linspace(0, 1, num_bars))

bars = plt.bar(grouped_paris.index, grouped_paris.values, color=colors)

for bar, value in zip(bars, grouped_paris.values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f"{value:.2f}",
             ha='center', va='bottom', fontsize=10)

plt.xlabel("Polluant")
plt.ylabel("Mean Value")
plt.title("Mean Value of Pollutants in Paris")
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
paris_pol = [p for p in paris["Polluant"].unique().tolist()]

# %%
horizontal_lines = {
    'NO': 200,
    'NO2': 200,
    'NOX as NO2': 200,
    'PM10': 50,
    'O3': 120,
    'PM2.5': 25,
    'CO': 10,
}

# %%
fig, axs = plt.subplots(4,2, figsize=(14,12))
for i,p in enumerate(paris_pol):
    ax = axs[i//2,i%2]

    pollutant_data = paris[paris["Polluant"] == p]

   # Plot the data
    ax.plot(pollutant_data['date'], pollutant_data['valeur'])
    ax.set_title(p)
    ax.set_xlabel('Date')
    ax.set_ylabel('Value')
    ax.grid(True)

    if p in horizontal_lines:
        ax.axhline(y=horizontal_lines[p], color='red', linestyle='--', label='Threshold')
        ax.legend()

#Hide unused
axes = axs.flatten()
for j in range(len(paris_pol), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
# plt.savefig("val_pollutants_threshold.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# Conclusions:
#
# Some interesting patterns here can be explained by meteorological conditions and chemical behaviors:
#
# * Pollutants directly related to human activity - especially $NO$, $NO_2$ and $NO_x$ as $NO_2$ are higher in winter. This can be explained by increased emissions from heating sources.
# * For $NO$ specifically (as example), is quickly converted in the presence of sunlight, which explains higher levels in winter
# * $O_3$ levels are inversed: higher in summer. This is because $0_3$ is a secondary pollutant formed through reaction involving sunlight, which is higher in summer. $0_3$ reacts with $NO$ (and is converted into another chemical). Because $NO$ levels are lower in summer, less $O_3$ is converted.
# * We sometime surpass the threshold of pollution in Paris.
